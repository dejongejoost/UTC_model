# %%
import nengo
import nengolib
import numpy as np
import scipy
# %pylab inline
import pylab

from nengo.utils.matplotlib import rasterplot
from nengo.dists import Choice
from nengo.utils.ensemble import response_curves, tuning_curves

import matplotlib.collections as mcol

# %run dashedlines.py
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/Joost/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
plt.rcParams['lines.marker'] = ''
plt.rcParams['font.size'] = 16
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['legend.fontsize'] = 14
plt.rcParams['legend.handlelength'] = 3

# %% [markdown]
# ## Neural Engineering Framework demo

# %%
ens_1d.gain

# %%
# Tuning curves: bias and intercept
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharey=True)

# vary gain (alpha)
model = nengo.Network()
with model:
    ens_1d = nengo.Ensemble(5, dimensions=1)
    
    ens_1d.bias = Choice([1])  # All neurons have x-intercept -0.2
    ens_1d.encoders = Choice([[1]])  # All neurons have encoder [1]
    ens_1d.gain = np.linspace(0.5, 1.5, num=5)

with nengo.Simulator(model) as sim:
    ax1.plot(*tuning_curves(ens_1d, sim), color='black')

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.set_ylabel("Firing rate (Hz)")
ax1.set_xlabel("<x, e>")
ax1.set_title(r'Varying gain ($\alpha$)')

# vary intecept
model = nengo.Network()
with model:
    ens_1d = nengo.Ensemble(5, dimensions=1)
    
    ens_1d.bias = np.linspace(0.5, 1.5, num=5)  # All neurons have x-intercept -0.2
    ens_1d.encoders = Choice([[1]])  # All neurons have encoder [1]
    ens_1d.gain = Choice([1])

with nengo.Simulator(model) as sim:
    ax2.plot(*tuning_curves(ens_1d, sim), color='black')

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.set_xlabel("<x, e>")
ax2.set_title(r'Varying bias ($\beta$)')

fig.savefig('gain_bias.png', dpi=400, bbox_inches='tight')
fig.savefig('gain_bias.tiff', dpi=1000, bbox_inches='tight')
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.

# %%
#parameters
#inputs = np.concatenate([np.zeros(100), np.ones(900)])
#inputs = nengo.processes.PresentInput(inputs, presentation_time = 0.001)
process = nengo.processes.WhiteSignal(30.0, high=1.5, y0=0)
tau_probe = 0.01  # to filter the spikes
n_neurons_pq = 100
q = 10
theta = 2

with nengolib.Network(seed=0) as model:
    LMT = nengolib.networks.RollingWindow(theta=theta, n_neurons=n_neurons_pq*q, 
        dimensions=q, process=None, legendre=True, neuron_type=nengo.LIF(), 
        realizer=nengolib.signal.realizers.Identity())
    
    a = nengo.Ensemble(n_neurons=100, dimensions=1, max_rates=nengo.dists.Uniform(20, 50))
    b = nengo.Ensemble(n_neurons=100, dimensions=1, max_rates=nengo.dists.Uniform(20, 50))
    
    stim = nengo.Node(output = process)

    nengo.Connection(stim, LMT.input, synapse=None)
    nengo.Connection(stim, a, synapse=0.05)
    nengo.Connection(stim, b, function=lambda x: x**2, synapse=0.05)
    
    p_stim_unfiltered = nengo.Probe(stim, synapse=None)
    p_stim = nengo.Probe(stim, synapse=None)
    p_a = nengo.Probe(a, synapse=0.05)
    p_b = nengo.Probe(b, synapse=0.05)
    p_a_spikes = nengo.Probe(a.neurons, 'spikes')
    p_x = nengo.Probe(LMT.state, synapse=tau_probe)  # for later analysis
    
with nengo.Simulator(model, seed=1) as sim:
    sim.run(5.0)
# Out:
# /Users/Joost/anaconda3/lib/python3.7/site-packages/scipy/signal/filter_design.py:1619: BadCoefficients: Badly conditioned filter coefficients (numerator): the results may be meaningless
#   "results may be meaningless", BadCoefficients)
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.

# %%
i = 17

# %%
fig, ax = plt.subplots(figsize=(6, 6))
xrange, activity = nengo.utils.ensemble.tuning_curves(a, sim)
tuning_plot = ax.plot(xrange, activity, lw=1, alpha=0.1, color='black')
tuning_plot = ax.plot(xrange, activity[:, i:i+2], lw=3.5)
ax.set_xlabel('<x, e>', size=16)
ax.set_ylabel('firing rate (Hz)', size=16)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_xticks(np.arange(-1, 1.5, 0.5))
ax.tick_params(axis='both', which='major', labelsize=16)

fig.savefig('tuning_curves_highlighted.png', dpi=400)
fig.savefig('tuning_curves_highlighted.tiff', dpi=1000, bbox_inches='tight')

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(16, 16), 
                                         sharex=True)

ax1.plot(sim.trange(), sim.data[p_stim],
         color='black', lw=2)
ax2.plot(sim.trange(), sim.data[p_a_spikes][:,i:i+2]/1000, lw=2)
ax2.plot(sim.trange(), sim.data[p_a_spikes][:,2:7]/1000, lw=2,
         color='black', alpha=0.05)

ax3.plot(sim.trange(), nengo.Lowpass(0.05).filt(sim.data[p_a_spikes][:,i:i+2]))
ax3.plot(sim.trange(), nengo.Lowpass(0.05).filt(sim.data[p_a_spikes][:,2:7]),
         color='black', alpha=0.05)

ax4.plot(sim.trange(), sim.data[p_a], color='black', label='$x$')
ax4.plot(sim.trange(), sim.data[p_b], color='grey', alpha=0.8, label='$x^2$')

ax4.legend(fontsize=20)

ax4.set_xlabel('time (s)', size=24)

ax1.tick_params(axis='both', which='major', labelsize=16)
ax4.tick_params(axis='both', which='major', labelsize=16)
ax1.set_ylim([-1.2, 1.2])
ax1.set_yticks([-1, -0.5, 0, 0.5, 1.])
ax2.set_yticks([])
ax3.set_yticks([])
ax4.set_ylim([-1.2, 1.2])
ax4.set_yticks([-1, -0.5, 0, 0.5, 1.])

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax4.spines['top'].set_visible(False)
ax4.spines['right'].set_visible(False)

#fig.savefig('principles_1_2.svg')

# %%
fig, ax = plt.subplots(figsize=(6, 6))

#ax.axis('square')
#ax.axis('off')

tuning_plot = ax.plot(xrange, activity[:, 2], lw=5, color='black')

#ax.axis('square')
ax.axis('off')

fig.savefig('tuning_curve.svg', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(6, 6))

#ax.axis('square')
#ax.axis('off')

ax.plot(np.linspace(0, 500, num=500),
        nengo.Lowpass(0.05).filt(np.concatenate([np.zeros(150),
                                                  np.array([1000]), 
                                                  np.zeros(349)])),
        color='black', lw=5)

#ax.axis('square')
ax.axis('off')

fig.savefig('lowpass.svg', bbox_inches='tight')

# %% [markdown]
# ### Delaying an input

# %%
from matplotlib.patches import ConnectionPatch

fig = plt.figure(constrained_layout=False, figsize=(16, 8))
gs = fig.add_gridspec(2, 5, wspace=0, hspace=0.5)

ax1 = fig.add_subplot(gs[0,:])
ax2 = fig.add_subplot(gs[1,:], sharey=ax1, sharex=ax1)

start = 1
ax1.plot(sim.trange(), sim.data[p_stim],
        color='#8c000fff', lw=3)

delay = int(theta*1000)
delayed_stim = np.concatenate([np.zeros(delay), sim.data[p_stim][:-delay].T[0]])
ax2.plot(sim.trange(), delayed_stim, color='black', lw=3)

ax1.set_ylim([-1.2, 1.2])
ax2.set_ylim([-1.2, 1.2])

# draw 'delay' lines and points
xyB = (start, -1.2)
xyA = (start+theta, -1.2)

con = ConnectionPatch(xyA=xyA, xyB=xyB, coordsA='data', coordsB='data',
                     axesA=ax2, axesB=ax1, color='black', ls=(0, (2, 4)),
                     arrowstyle='<-',
                     lw=3)
ax2.add_artist(con)

ax1.scatter(xyB[0], sim.data[p_stim][int(start*1000)], 
            c='black', s=300, lw=5, edgecolors='lightgrey')
ax2.scatter(xyA[0], sim.data[p_stim][int(start*1000)],
            c='black', s=300, lw=5, edgecolors='lightgrey')

for i in np.arange(start+0.1, start+theta+0.1, .1):
    xyB = (i, -1.2)
    xyA = (theta+i, -1.2)

    con = ConnectionPatch(xyA=xyA, xyB=xyB, coordsA='data', coordsB='data',
                         axesA=ax2, axesB=ax1, color='grey', ls=(0, (5, 10)), zorder=0)

    ax2.add_artist(con)
    
    ax1.scatter(xyB[0], sim.data[p_stim][int(i*1000)], 
                color='black', s=80, zorder=100)
    ax2.scatter(xyA[0], sim.data[p_stim][int(i*1000)], 
                color='black', s=80, zorder=100)

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)

ax2.set_xlabel('real time (s)', fontsize=20)

fig.savefig('delaying_input.svg')
fig.savefig('delaying_input.tiff', dpi=1000, bbox_inches='tight')

# %%
from matplotlib.patches import ConnectionPatch

fig = plt.figure(constrained_layout=False, figsize=(16, 8))
gs = fig.add_gridspec(2, 5, wspace=0, hspace=0.5)

ax1 = fig.add_subplot(gs[0,:])
ax2 = fig.add_subplot(gs[1,1:3], sharey=ax1)

start = 1
ax1.axvline(x = 3, linestyle='--', c='black', alpha=0.5)
ax1.plot(sim.trange(), sim.data[p_stim],
        color='#8c000fff', lw=3)

trange_internal = np.linspace(1, 3, num=2000)
#ax2.plot(trange_internal, 
#         sim.data[p_stim][int(start*1000): int((start+theta)*1000)],
#         c='black', lw=4, ls='-', label='estimated')

ax1.set_ylim([-1.2, 1.2])
ax2.set_ylim([-1.2, 1.2])

# draw 'delay' lines and points
xyB = (start, -1.2)
xyA = (start, -1.2)

ax1.scatter(xyB[0], sim.data[p_stim][int(start*1000)], 
            c='black', s=300, lw=5, edgecolors='lightgrey')
ax2.scatter(xyA[0], sim.data[p_stim][int(start*1000)],
            c='black', s=300, lw=5, edgecolors='lightgrey')

for i in np.arange(start+0.1, start+theta+0.1, .1):
    xyB = (i, -1.2)
    xyA = (i, -1.2)

    ax1.scatter(xyB[0], sim.data[p_stim][int(i*1000)], 
                color='black', s=80, zorder=100)
    ax2.scatter(xyA[0], sim.data[p_stim][int(i*1000)],
                color='black', s=80, zorder=100)

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax1.set_xlabel('real time (s)', size=20)
ax2.set_xlabel('internal time', size=20)
#ax2.spines['right'].set_visible(False)

ax2.set_facecolor('whitesmoke')
ax2.set_xlim([np.min(trange_internal)-0.15, 
              np.max(trange_internal)+0.05])

fig.savefig('infinite_memory_solution.svg')

# %% [markdown]
# ### Legendre Memory Network

# %%
fig = plt.figure(constrained_layout=False, figsize=(16, 20))
gs = fig.add_gridspec(11, 5, wspace=0, hspace=0.5)

t = 3000
colors = plt.cm.GnBu(np.linspace(0.2, 1, num=q))[::-1]

ax1 = fig.add_subplot(gs[0:2,:])
ax2 = fig.add_subplot(gs[2:4,:], sharey=ax1)
ax3 = fig.add_subplot(gs[5:7,1:3])
ax4 = fig.add_subplot(gs[7:9,1:3], sharey=ax3)
ax5 = fig.add_subplot(gs[9:11,1:3], sharey=ax4)

ax1.plot(sim.trange(), sim.data[p_stim], c='#8c000fff', lw=3)
ax1.axvline(x = int(t/1000), linestyle='--', c='black', alpha=0.5)

B = LMT.basis()
ax2.axvline(x = int(t/1000), linestyle='--', c='black', alpha = 0.5)
for i in range(0,q):
    ax2.plot(sim.trange(), sim.data[p_x][:,i], lw=2, alpha=0.4,
             color=colors[i])
    ax2.scatter(int(t/1000), sim.data[p_x][t][i], 120, edgecolors='black', zorder=20,
                color=colors[i])
    
    ax3.plot(np.linspace(1, 3, num=1000), B[::-1, i], lw=2,
             color=colors[i], label='{}'.format(i))
    ax4.plot(np.linspace(1, 3, num=1000), sim.data[p_x][t,i] * B[::-1,i], lw=2,
             color=colors[i])

line = [[(0, 0)]]
# set up the proxy artist
lc = mcol.LineCollection(q * line, colors=colors)
# create the legend
leg = ax3.legend([lc], ['dim'], handler_map={type(lc): HandlerDashedLines()},
           handlelength=10, handleheight=0.75, fontsize=18, loc='lower left')

ax5.plot(np.linspace(1, 3, num=1000), 
         np.sum(sim.data[p_x][t] * B, axis=1)[::-1], 
         c='black', lw=4, ls='-', label='estimated')
ax5.plot(np.linspace(1, 3, num=int(theta*1000)), 
         sim.data[p_stim][t-int(theta*1000):t], c='#8c000fff', lw=3, label='actual')
ax5.legend(fontsize=16)

ax1.tick_params(axis='both', which='major', labelsize=16)
ax2.tick_params(axis='both', which='major', labelsize=16)
ax3.tick_params(axis='both', which='major', labelsize=16)
ax4.tick_params(axis='both', which='major', labelsize=16)
ax5.tick_params(axis='both', which='major', labelsize=16)


ax1.set_xticks([])
ax2.set_xlabel('real time (s)', size=20)
ax3.set_xticks(np.linspace(1, 3, num=10))
ax3.set_xticklabels([])
ax4.set_xticks(np.linspace(1, 3, num=10))
ax4.set_xticklabels([])
ax5.set_xticks(np.linspace(1, 3, num=10))
ax5.set_xticklabels([r'$-\theta$', '', '', '', '', '', '', '', '', 0], 
                    size=24)
ax5.set_xlabel('internal time', size=20)

ax3.set_facecolor('whitesmoke')
ax4.set_facecolor('whitesmoke')
ax5.set_facecolor('whitesmoke')

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)
#ax3.spines['right'].set_visible(False)
#ax4.spines['top'].set_visible(False)
#ax4.spines['right'].set_visible(False)
#ax5.spines['top'].set_visible(False)
#ax5.spines['right'].set_visible(False)

#fig.savefig('legendre_memory_demo.svg')

# %% [markdown]
# ## Flexible window

# %%
#parameters
process = nengo.processes.WhiteSignal(30.0, high=1.5, y0=0, seed=0)
tau_probe = 0.01  # to filter the spikes
n_neurons_pq = 100
q = 10
theta = 2

with nengolib.Network(seed=0) as model:
    
    LMT1 = nengolib.networks.RollingWindow(theta=theta, n_neurons=n_neurons_pq*q, 
        dimensions=q, process=None, legendre=True, neuron_type=nengo.LIF(), 
        realizer=nengolib.signal.realizers.Identity())
    LMT2 = nengolib.networks.RollingWindow(theta=theta/2., 
                                           n_neurons=n_neurons_pq*q, 
        dimensions=q, process=None, legendre=True, neuron_type=nengo.LIF(), 
        realizer=nengolib.signal.realizers.Identity())
       
    signal = process.run(20.0)
    signal1 = signal
    signal2 = scipy.signal.resample(signal, 10000)

    def signal_func(t, signal):
        return signal[int(t*1000)]
    
    stim1 = nengo.Node(lambda t: signal_func(t, signal1))
    stim2 = nengo.Node(lambda t: signal_func(t, signal2))
    
    nengo.Connection(stim1, LMT1.input, synapse=None)
    nengo.Connection(stim2, LMT2.input, synapse=None)
    
    p_stim1 = nengo.Probe(stim1, synapse=None)
    p_stim2 = nengo.Probe(stim2, synapse=None)
    
    p_x1 = nengo.Probe(LMT1.state, synapse=None)
    p_x2 = nengo.Probe(LMT2.state, synapse=None)
    #p_stim = nengo.Probe(stim, synapse=None)
    #p_a = nengo.Probe(a, synapse=0.05)
    #p_b = nengo.Probe(b, synapse=0.05)
    #p_a_spikes = nengo.Probe(a.neurons, 'spikes')
    #p_x = nengo.Probe(LMT.state, synapse=tau_probe)  # for later analysis
    
with nengo.Simulator(model, seed=0) as sim:
    sim.run(9.999)
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.

# %%
B = LMT1.basis()

# %%
fig = plt.figure(constrained_layout=False, figsize=(16, 12))
gs = fig.add_gridspec(3, 5, wspace=0, hspace=0.5)

ax1 = fig.add_subplot(gs[0,:])
ax2 = fig.add_subplot(gs[1,2:3], sharey=ax1)
ax3 = fig.add_subplot(gs[2,1:3])

trange = np.linspace(0, 5., num=5000)
ax1.plot(trange,
         sim.data[p_stim1][3000:8000],
         lw=3, alpha=0.2, color='cornflowerblue')
trange = np.linspace(1., 3., num=2000)
ax1.plot(trange,
         sim.data[p_stim1][4000:6000],
         lw=3.5, color='cornflowerblue')

trange = np.linspace(0, 5., num=5000)
ax1.plot(trange,
         sim.data[p_stim2][:5000], lw=3,  c='#8c000fff',
         alpha=0.2)
trange = np.linspace(2., 3., num=1000)
ax1.plot(trange,
         sim.data[p_stim2][2000:3000], lw=3.5,  c='#8c000fff')

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
#ax1.set_xlim([0, 5.])
ax1.set_xlabel('real time (s)', size=20, horizontalalignment='right', x=1)
ax1.set_ylim([-1.4, 1.4])

# Internal timelines
trange_internal = np.linspace(0, 2, num=1000)
t = 6000
theta = 2
ax3.set_facecolor('whitesmoke')
ax3.plot(np.linspace(0, 2, num=1000), 
         np.sum(nengo.Alpha(0.01).filt(sim.data[p_x1])[t] * B, axis=1)[::-1], 
         lw=3, label='estimated', color='black')
ax3.plot(np.linspace(0, 2, num=int(theta*1000)), 
         sim.data[p_stim1][t-int(theta*1000):t], c='cornflowerblue', lw=3, label='actual')

ax3.set_xticks(np.linspace(0, 2, num=10))
ax3.set_xticklabels([r'$-\theta$', '', '', '', '', '', '', '', '', 0], 
                    size=24)

ax3.set_ylim([-1.4, 1.4])
ax3.set_xlim([np.min(trange_internal)-0.05, 
              np.max(trange_internal)+0.05])
ax3.set_xlabel('internal time', size=20)


t = 3000
theta = 1
ax2.set_facecolor('whitesmoke')
ax2.plot(np.linspace(0, 2, num=int(theta*1000)), 
         sim.data[p_stim2][t-int(theta*1000):t], c='#8c000fff', lw=3, label='actual')
ax2.plot(np.linspace(0, 2, num=1000), 
         np.sum(nengo.Alpha(0.01).filt(sim.data[p_x2])[t] * B, axis=1)[::-1],
         lw=3, label='estimated', color='black')
ax2.set_xticks(np.linspace(0, 2, num=10))
ax2.set_xticklabels([r'$-\theta$', '', '', '', '', '', '', '', '', 0], 
                    size=24)

ax2.spines['top'].set_visible(False)
ax2.set_ylim([-1.4, 1.4])
ax2.set_xlim([np.min(trange_internal)-0.1, 
              np.max(trange_internal)+0.1])


#ax.plot(scipy.signal.resample(sim.data[p_stim_unfiltered], 4900))
#ax.plot(scipy.signal.resample(sim.data[p_stim_unfiltered], 4800))
#ax.plot(scipy.signal.resample(sim.data[p_stim_unfiltered], 4700))
fig.savefig('legendre_memory_flexible_demo.svg')

# %% [markdown]
# ### Video time

# %%
#parameters
#inputs = np.concatenate([np.zeros(100), np.ones(900)])
#inputs = nengo.processes.PresentInput(inputs, presentation_time = 0.001)
process = nengo.processes.WhiteSignal(30.0, high=1.5, y0=0)
tau_probe = 0.01  # to filter the spikes
n_neurons_pq = 100
q = 9
theta = 2

with nengolib.Network(seed=0) as model:
    LMT = nengolib.networks.RollingWindow(theta=theta, n_neurons=n_neurons_pq*q, 
        dimensions=q, process=None, legendre=True, neuron_type=nengo.Direct(), 
        realizer=nengolib.signal.realizers.Identity())
    
    #a = nengo.Ensemble(n_neurons=100, dimensions=1, max_rates=nengo.dists.Uniform(20, 50))
    #b = nengo.Ensemble(n_neurons=100, dimensions=1, max_rates=nengo.dists.Uniform(20, 50))
    
    stim = nengo.Node(output = process)

    nengo.Connection(stim, LMT.input, synapse=None)
    #nengo.Connection(stim, a, synapse=0.05)
    #nengo.Connection(stim, b, function=lambda x: x**2, synapse=0.05)
    
    p_stim_unfiltered = nengo.Probe(stim, synapse=None)
    p_stim = nengo.Probe(stim, synapse=None)
    #p_a = nengo.Probe(a, synapse=0.05)
    #p_b = nengo.Probe(b, synapse=0.05)
    #p_a_spikes = nengo.Probe(a.neurons, 'spikes')
    p_x = nengo.Probe(LMT.state, synapse=None)  # for later analysis
    
with nengo.Simulator(model, seed=1) as sim:
    sim.run(10.1)

# %%
int(theta)

# %%
fig = plt.figure(constrained_layout=False, figsize=(16, 20))
n_hpanels = int(2*theta)
gs = fig.add_gridspec(11, 4, wspace=0, hspace=0.5)

t = 7000
colors = plt.cm.GnBu(np.linspace(0.2, 1, num=q))[::-1]

ax1 = fig.add_subplot(gs[0:2,:])
ax2 = fig.add_subplot(gs[2:4,:], sharey=ax1)
ax3 = fig.add_subplot(gs[5:7, 2:])
ax4 = fig.add_subplot(gs[7:9, 2:], sharey=ax3)
ax5 = fig.add_subplot(gs[9:11, 2:], sharey=ax4)

trange_real = np.linspace(t-int(2*theta*1000), t, num=int(2*theta*1000)).astype(int)
ax1.plot(trange_real/1000, sim.data[p_stim][trange_real], c='#8c000fff', lw=3)
ax1.axvline(x = int(t)/1000, linestyle='--', c='black', alpha=0.5)

B = LMT.basis()
trange_internal = np.linspace(t-int(theta*1000), t, num=1000).astype(int)
ax2.axvline(x = int(t)/1000, linestyle='--', c='black', alpha = 0.5)
for i in range(0,q):
    ax2.plot(trange_real/1000, sim.data[p_x][trange_real,i], lw=2, alpha=0.4,
             color=colors[i])
    ax2.scatter(int(t)/1000, sim.data[p_x][t][i], 120, edgecolors='black', zorder=20,
                color=colors[i])
    
    ax3.plot(trange_internal/1000, 
             B[::-1, i], lw=2,
             color=colors[i], label='{}'.format(i))
    ax4.plot(trange_internal/1000, 
             sim.data[p_x][t,i] * B[::-1,i], lw=2,
             color=colors[i])

line = [[(0, 0)]]
# set up the proxy artist
lc = mcol.LineCollection(q * line, colors=colors)
# create the legend
leg = ax3.legend([lc], ['dim'], handler_map={type(lc): HandlerDashedLines()},
           handlelength=10, handleheight=0.75, fontsize=18, loc='lower left')

ax5.plot(trange_internal/1000, 
         sim.data[p_stim][trange_internal], c='#8c000fff', lw=3, label='actual')
ax5.plot(trange_internal/1000, 
         np.sum(sim.data[p_x][t] * B, axis=1)[::-1], 
         c='black', lw=4, ls='-', label='estimated')

ax5.legend(loc='upper left', fontsize=16)

ax1.tick_params(axis='both', which='major', labelsize=16)
ax2.tick_params(axis='both', which='major', labelsize=16)
ax3.tick_params(axis='both', which='major', labelsize=16)
ax4.tick_params(axis='both', which='major', labelsize=16)
ax5.tick_params(axis='both', which='major', labelsize=16)

ax1.set_xticks([])
ax2.set_xlabel('real time (s)', size=20)
ax3.set_xticks(np.linspace(t-int(theta*1000), t, num=10).astype(int)/1000)
ax3.set_xticklabels([])
ax4.set_xticks(np.linspace(t-int(theta*1000), t, num=10).astype(int)/1000)
ax4.set_xticklabels([])
ax5.set_xticks(np.linspace(t-int(theta*1000), t, num=10).astype(int)/1000)
ax5.set_xticklabels([r'$-\theta$', '', '', '', '', '', '', '', '', 0], 
                    size=24)
ax5.set_xlabel('internal time', size=20)

ax3.set_facecolor('whitesmoke')
ax4.set_facecolor('whitesmoke')
ax5.set_facecolor('whitesmoke')

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
#ax3.spines['top'].set_visible(False)
#ax3.spines['right'].set_visible(False)
#ax4.spines['top'].set_visible(False)
#ax4.spines['right'].set_visible(False)
#ax5.spines['top'].set_visible(False)
#ax5.spines['right'].set_visible(False)

ax1.set_xlim([np.min(trange_real/1000)-0.05, 
              np.max(trange_real/1000)+0.05])
ax2.set_xlim([np.min(trange_real/1000)-0.05, 
              np.max(trange_real/1000)+0.05])

ax3.set_xlim([np.min(trange_internal/1000), 
              np.max(trange_internal/1000)+0.05])
ax4.set_xlim([np.min(trange_internal/1000), 
              np.max(trange_internal/1000)+0.05])
ax5.set_xlim([np.min(trange_internal/1000), 
              np.max(trange_internal/1000)+0.05])


ax2.set_ylim([-1.3, 1.3])
#ax4.set_xlim([np.min(trange_internal/1000), np.max(trange_internal/1000)])
#ax1.set_xlim([np.min(trange_internal/1000), np.max(trange_internal/1000)])


#fig.savefig('legendre_memory_demo.svg')

# %%
np.arange(0, 9000, 100)

# %%
import pathlib
import os
pathlib.Path().absolute()

# %%
os.mkdir('vid1')

# %%
# %%capture
for t in np.arange(4000, 10000, 10):

    fig = plt.figure(constrained_layout=False, figsize=(16, 20))
    gs = fig.add_gridspec(11, 4, wspace=0, hspace=0.5)

    colors = plt.cm.GnBu(np.linspace(0.2, 1, num=q))[::-1]

    ax1 = fig.add_subplot(gs[0:2,:])
    ax2 = fig.add_subplot(gs[2:4,:], sharey=ax1)
    ax3 = fig.add_subplot(gs[5:7, 2:])
    ax4 = fig.add_subplot(gs[7:9, 2:], sharey=ax3)
    ax5 = fig.add_subplot(gs[9:11, 2:], sharey=ax4)

    trange_real = np.linspace(t-int(2*theta*1000), t, num=int(2*theta*1000)).astype(int)
    ax1.plot(trange_real/1000, sim.data[p_stim][trange_real], c='#8c000fff', lw=3)
    ax1.axvline(x = int(t)/1000, linestyle='--', c='black', alpha=0.5)

    B = LMT.basis()
    trange_internal = np.linspace(t-int(theta*1000), t, num=1000).astype(int)
    ax2.axvline(x = int(t)/1000, linestyle='--', c='black', alpha = 0.5)
    for i in range(0,q):
        ax2.plot(trange_real/1000, sim.data[p_x][trange_real,i], lw=2, alpha=0.4,
                 color=colors[i])
        ax2.scatter(int(t)/1000, sim.data[p_x][t][i], 120, edgecolors='black', zorder=20,
                    color=colors[i])

        ax3.plot(trange_internal/1000, 
                 B[::-1, i], lw=2,
                 color=colors[i], label='{}'.format(i))
        ax4.plot(trange_internal/1000, 
                 sim.data[p_x][t,i] * B[::-1,i], lw=2,
                 color=colors[i])

    line = [[(0, 0)]]
    # set up the proxy artist
    lc = mcol.LineCollection(q * line, colors=colors)
    # create the legend
    leg = ax3.legend([lc], ['dim'], handler_map={type(lc): HandlerDashedLines()},
               handlelength=10, handleheight=0.75, fontsize=18, loc='lower left')

    ax5.plot(trange_internal/1000, 
             sim.data[p_stim][trange_internal], c='#8c000fff', lw=3, label='actual')
    ax5.plot(trange_internal/1000, 
             np.sum(sim.data[p_x][t] * B, axis=1)[::-1], 
             c='black', lw=4, ls='-', label='estimated')

    ax5.legend(loc='upper left', fontsize=16)

    ax1.tick_params(axis='both', which='major', labelsize=16)
    ax2.tick_params(axis='both', which='major', labelsize=16)
    ax3.tick_params(axis='both', which='major', labelsize=16)
    ax4.tick_params(axis='both', which='major', labelsize=16)
    ax5.tick_params(axis='both', which='major', labelsize=16)

    ax1.set_xticks([])
    ax2.set_xlabel('real time (s)', size=20)
    ax3.set_xticks(np.linspace(t-int(theta*1000), t, num=10).astype(int)/1000)
    ax3.set_xticklabels([])
    ax4.set_xticks(np.linspace(t-int(theta*1000), t, num=10).astype(int)/1000)
    ax4.set_xticklabels([])
    ax5.set_xticks(np.linspace(t-int(theta*1000), t, num=10).astype(int)/1000)
    ax5.set_xticklabels([r'$-\theta$', '', '', '', '', '', '', '', '', 0], 
                        size=24)
    ax5.set_xlabel('internal time', size=20)

    ax3.set_facecolor('whitesmoke')
    ax4.set_facecolor('whitesmoke')
    ax5.set_facecolor('whitesmoke')

    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax2.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    #ax3.spines['top'].set_visible(False)
    #ax3.spines['right'].set_visible(False)
    #ax4.spines['top'].set_visible(False)
    #ax4.spines['right'].set_visible(False)
    #ax5.spines['top'].set_visible(False)
    #ax5.spines['right'].set_visible(False)

    ax1.set_xlim([np.min(trange_real/1000)-0.05, 
                  np.max(trange_real/1000)+0.05])
    ax2.set_xlim([np.min(trange_real/1000)-0.05, 
                  np.max(trange_real/1000)+0.05])

    ax3.set_xlim([np.min(trange_internal/1000), 
                  np.max(trange_internal/1000)+0.05])
    ax4.set_xlim([np.min(trange_internal/1000), 
                  np.max(trange_internal/1000)+0.05])
    ax5.set_xlim([np.min(trange_internal/1000), 
                  np.max(trange_internal/1000)+0.05])
    
    ax1.set_ylim([-1.1, 1.1])
    ax2.set_ylim([-1.3, 1.3])
    ax3.set_ylim([-1.1, 1.1])
    ax4.set_ylim([-1.1, 1.1])
    ax5.set_ylim([-1.1, 1.1])

    #ax4.set_xlim([np.min(trange_internal/1000), np.max(trange_internal/1000)])
    #ax1.set_xlim([np.min(trange_internal/1000), np.max(trange_internal/1000)])


    #fig.savefig('legendre_memory_demo.svg')
    fig.savefig(str(pathlib.Path().absolute())+'/vid1/{}'.format(t))

# %%
np.min(sim.data[p_x])

# %%
import cv2

# %%
image_folder = 'vid1'
video_name = 'vid1.avi'

files = os.listdir(image_folder)
files = filter(lambda x:x.endswith(".png"), files)

images = [img for img in sorted(files, key=lambda x: int(os.path.splitext(x.split('.')[0])[0])) if img.endswith(".png")]
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

video = cv2.VideoWriter(video_name, 0, 20, (width,height))

for image in images:
    video.write(cv2.imread(os.path.join(image_folder, image)))

cv2.destroyAllWindows()
video.release()

# %% [markdown]
# ### Time estimation with LDNs

# %%
# %run LMU_timing.py

# %%
D = 32
dim = 9

def stimulus_function(t):
    if t > 0.5 and t < 0.75:
        return 'A'
    elif t > 0.75 and t < 1.:
        return 'B'
    elif t > 1. and t < 1.25:
        return 'C'
    elif t > 1.25 and t < 1.5:
        return 'D'
    else:
        return 0

vocab = spa.Vocabulary(D)
vocab.populate('A;B;C;D;T')

# %%
# %%capture
LMU_timing().run(dimensions=dim,
                 D=D,
                 full_output=True,
                 direct_mode=False,
                 gain_i=1.,
                 effective_theta=1.5,
                 vocab=vocab,
                 task_type = 'prospective_sensory',
                 stimulus_function=stimulus_function,
                 data_dir='spa_time_estimation_demo',
                 t_onset=0.5, 
                 t_offset=1.5,
                 
                 trial_duration=2.5)

# %%
def readout_window(state, D, readout_time, dim, sp):
    rw = nengolib.networks.RollingWindow(n_neurons=100,
                                             theta = 1,
                                             dimensions=dim,
                                             process=None,
                                             legendre=True,
                                             realizer=nengolib.signal.realizers.Identity())
    basis = rw.basis()
    temp = []
    history_matrix = [] # list of reconstructed SPs 
    for d in range(0, dim):
        temp.append(spa.similarity(nengo.Alpha(0.05).filt(state)[readout_time, :, d], 
                                   sp,
                                   normalize=False)[0])
    
    history = np.sum(basis * np.asarray(temp), axis=1)[::-1]
    
    return history

# %%
est_data = pytry.read('spa_time_estimation_demo')

# %%
est_dt = pd.DataFrame(est_data)

# %%
# read in data
state_input = est_dt['state'].values[0]
state = est_dt['x'].values[0]

# %%
plt.plot(nengo.Alpha(0.01).filt(spa.similarity(state_input, vocab)))

# %%
temp = readout_window(np.moveaxis(state, 1, 0), D, 1750, dim, vocab['T'].v)
plt.plot(temp)

# %%
plt.plot(np.arange(0, 1., 0.001), abs(temp))
plt.fill_between(np.arange(0, 1, 0.001), abs(temp), alpha=0.1)

# %%
for i in ['A', 'B', 'C', 'D']:
    temp = readout_window(np.moveaxis(state, 1, 0), D, 1750, dim, vocab[i].v)
    plt.plot(np.arange(0, 1., 0.001), abs(temp))
    plt.fill_between(np.arange(0, 1, 0.001), abs(temp), alpha=0.1)

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
fig = plt.figure(constrained_layout=False, figsize=(15, 10))
gs = fig.add_gridspec(4, 7, wspace=0, hspace=1)

t = 1750

ax1 = fig.add_subplot(gs[0:2,:])
ax2 = fig.add_subplot(gs[2:4,1:])

trange_real = np.arange(0, t).astype(int)
for i in np.arange(0,4):
    ax1.plot(trange_real/1000, 
             nengo.Alpha(0.02).filt(spa.similarity(state_input, vocab))[trange_real,i], 
             lw=3, color=colors[i+1])
ax1.axvline(x = int(t)/1000, linestyle='--', c='black', alpha=0.5)

trange_internal = np.linspace(t-int(theta*1000), t, num=1000).astype(int)
for i in np.arange(0,4):
    temp = readout_window(np.moveaxis(state, 1, 0), D, 1750, dim, vocab[SP_list[i]].v)
    ax2.plot(trange_internal/1000, temp, color=colors[i+1], lw=4)
    
ax5.legend(loc='upper left', fontsize=16)

ax1.tick_params(axis='both', which='major', labelsize=16)
ax2.tick_params(axis='both', which='major', labelsize=16)

ax1.set_xlabel('real time (s)', size=20)
ax2.set_xlabel('internal time', size=20)

ax2.set_facecolor('whitesmoke')

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

ax2.set_xticklabels([r'$-\theta$', '', '', '', '', '', '', '', 0], 
                        size=24)
ax2.set_xlabel('internal time', size=20)

ax1.set_xlim([np.min(trange_real/1000)-0.05, 
              np.max(trange_real/1000)+0.05])
ax2.set_xlim([np.min(trange_internal/1000), 
                  np.max(trange_internal/1000)+0.05])

ax1.set_ylim([-0.05, 1.])
ax2.set_ylim([-0.05, 1.])

fig.savefig('sp_time_estimation_all.png', dpi=400, bbox_inches='tight')

# %%
# %%capture
for i in np.arange(0, 4):
    fig = plt.figure(constrained_layout=False, figsize=(15, 10))
    gs = fig.add_gridspec(4, 7, wspace=0, hspace=1)

    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

    t = 1750

    ax1 = fig.add_subplot(gs[0:2,:])
    ax2 = fig.add_subplot(gs[2:4,1:])

    trange_real = np.arange(0, t).astype(int)
    for j in np.arange(0,4):
        ax1.plot(trange_real/1000, 
                 nengo.Alpha(0.02).filt(spa.similarity(state_input, vocab))[trange_real,j], 
                 lw=3, color=colors[j+1])
    ax1.axvline(x = int(t)/1000, linestyle='--', c='black', alpha=0.5)

    trange_internal = np.linspace(t-int(theta*1000), t, num=1000).astype(int)
    SP_list = ['A', 'B', 'C', 'D']
    for j in SP_list:
        temp = readout_window(np.moveaxis(state, 1, 0), D, 1750, dim, vocab[j].v)
        if j == SP_list[i]:
            ax2.plot(trange_internal/1000, abs(temp), color=colors[i+1])
            ax2.fill_between(trange_internal/1000, abs(temp), alpha=1, color=colors[i+1])
        else: 
            ax2.plot(trange_internal/1000, abs(temp), c='black', alpha=0.2)
            ax2.fill_between(trange_internal/1000, abs(temp), alpha=0.05, color='black')

    ax5.legend(loc='upper left', fontsize=16)

    ax1.tick_params(axis='both', which='major', labelsize=16)
    ax2.tick_params(axis='both', which='major', labelsize=16)

    ax1.set_xlabel('real time (s)', size=20)
    ax2.set_xlabel('internal time', size=20)

    ax2.set_facecolor('whitesmoke')
    
    ax2.set_xticklabels([r'$-\theta$', '', '', '', '', '', '', '', 0], 
                        size=24)
    ax2.set_xlabel('internal time', size=20)

    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)

    ax1.set_xlim([np.min(trange_real/1000)-0.05, 
                  np.max(trange_real/1000)+0.05])
    ax2.set_xlim([np.min(trange_internal/1000), 
                      np.max(trange_internal/1000)+0.05])

    ax1.set_ylim([-0.05, 1.])
    ax2.set_ylim([-0.05, 1.])

    fig.savefig('sp_time_estimation_{}.png'.format(SP_list[i]), dpi=400, bbox_inches='tight')

# %%
# %%capture
fig = plt.figure(constrained_layout=False, figsize=(15, 10))
gs = fig.add_gridspec(4, 7, wspace=0, hspace=1)

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

t = 1750

ax1 = fig.add_subplot(gs[0:2,:])
ax2 = fig.add_subplot(gs[2:4,1:])

trange_real = np.arange(0, t).astype(int)
for j in np.arange(0,4):
    ax1.plot(trange_real/1000, 
             nengo.Alpha(0.02).filt(spa.similarity(state_input, vocab))[trange_real,j], 
             lw=3, color=colors[j+1])
ax1.axvline(x = int(t)/1000, linestyle='--', c='black', alpha=0.5)

trange_internal = np.linspace(t-int(theta*1000), t, num=1000).astype(int)
SP_list = ['A', 'B', 'C', 'D']
for j in np.arange(0,4):
    temp = readout_window(np.moveaxis(state, 1, 0), D, 1750, dim, vocab[SP_list[j]].v)
    ax2.plot(trange_internal/1000, abs(temp), color=colors[j+1], zorder=50+j)
    ax2.fill_between(trange_internal/1000, abs(temp), alpha=1, color=colors[j+1], zorder=50+j)


ax5.legend(loc='upper left', fontsize=16)

ax1.tick_params(axis='both', which='major', labelsize=16)
ax2.tick_params(axis='both', which='major', labelsize=16)

ax1.set_xlabel('real time (s)', size=20)
ax2.set_xlabel('internal time', size=20)

ax2.set_facecolor('whitesmoke')

ax2.set_xticklabels([r'$-\theta$', '', '', '', '', '', '', '', 0], 
                    size=24)
ax2.set_xlabel('internal time', size=20)

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)

ax1.set_xlim([np.min(trange_real/1000)-0.05, 
              np.max(trange_real/1000)+0.05])
ax2.set_xlim([np.min(trange_internal/1000), 
                  np.max(trange_internal/1000)+0.05])

ax1.set_ylim([-0.05, 1.])
ax2.set_ylim([-0.05, 1.])

fig.savefig('sp_time_estimation_all_fill.png'.format(SP_list[i]), dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(constrained_layout=False, figsize=(15, 10))
gs = fig.add_gridspec(4, 7, wspace=0, hspace=1)

t = 1750

ax1 = fig.add_subplot(gs[0:2,:])
ax2 = fig.add_subplot(gs[2:4,1:])

trange_real = np.arange(0, t).astype(int)
ax1.plot(trange_real/1000, 
         nengo.Alpha(0.02).filt(spa.similarity(state_input, vocab))[trange_real,-1], lw=3)
ax1.axvline(x = int(t)/1000, linestyle='--', c='black', alpha=0.5)

trange_internal = np.linspace(t-int(theta*1000), t, num=1000).astype(int)
for i in ['T']:
    temp = readout_window(np.moveaxis(state, 1, 0), D, 1750, dim, vocab[i].v)
    ax2.plot(trange_internal/1000, abs(temp))
    ax2.fill_between(trange_internal/1000, abs(temp), alpha=1.)
    
ax5.legend(loc='upper left', fontsize=16)

ax1.tick_params(axis='both', which='major', labelsize=16)
ax2.tick_params(axis='both', which='major', labelsize=16)

ax1.set_xlabel('real time (s)', size=20)
ax2.set_xlabel('internal time', size=20)

ax2.set_facecolor('whitesmoke')

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)

ax2.set_xticklabels([r'$-\theta$', '', '', '', '', '', '', '', 0], 
                        size=24)
ax2.set_xlabel('internal time', size=20)

ax1.set_xlim([np.min(trange_real/1000)-0.05, 
              np.max(trange_real/1000)+0.05])
ax2.set_xlim([np.min(trange_internal/1000), 
                  np.max(trange_internal/1000)+0.05])

ax1.set_ylim([-0.05, 1.])
ax2.set_ylim([-0.05, 1.])

fig.savefig('sp_time_estimation_T.png', dpi=400, bbox_inches='tight')

# %% [markdown]
# ### Interference, normalization and attention: the movie

# %%
# %%capture

with spa.Network(seed=0) as network:
    vector_a = np.array([np.cos(np.pi/10), np.sin(np.pi/10)])

    def vb_func(t): 
        if t <= 2:
            g = t
        elif t > 2:
            g = 4 - t
        return np.array([np.cos(np.pi/10 + np.pi/2), np.sin(np.pi/10 + np.pi/2)]) * g

    input_a = nengo.Node(output=vector_a)
    input_b = nengo.Node(output=vb_func)

    a_ens = nengo.Ensemble(n_neurons=100, dimensions=2, radius=1)
    b_ens = nengo.Ensemble(n_neurons=100, dimensions=2, radius=1)

    wm_ens = nengo.Ensemble(n_neurons=100, neuron_type=nengo.LIF(),
                              dimensions=2, radius=1)

    r = nengo.Node(size_in=2)

    aa = nengo.Connection(input_a, a_ens)
    bb = nengo.Connection(input_b, b_ens)
    awm = nengo.Connection(a_ens, wm_ens)
    bwm = nengo.Connection(b_ens, wm_ens)
    readout = nengo.Connection(wm_ens, r)

    a_probe = nengo.Probe(a_ens)
    b_probe = nengo.Probe(b_ens)
    wm_probe = nengo.Probe(wm_ens)
    wm_encoders = nengo.Probe(wm_ens, 'scaled_encoders')
    spike_probe = nengo.Probe(wm_ens.neurons)

with nengo.Simulator(network) as sim:
    sim.run(4.)

#ax.plot(nengo.Alpha(0.02).filt(sim.data[wm_probe][:,0]),
#        color=colors[i])

# %%
plt.plot(nengo.Alpha(0.02).filt(sim.data[wm_probe]))

# %%
a_readout

# %%
def unit_vector(vector):
    """ Returns the unit vector of the vector.  """
    return vector / np.linalg.norm(vector)

def angle_between(v1, v2):
    """ Returns the angle in radians between vectors 'v1' and 'v2'::

            >>> angle_between((1, 0, 0), (0, 1, 0))
            1.5707963267948966
            >>> angle_between((1, 0, 0), (1, 0, 0))
            0.0
            >>> angle_between((1, 0, 0), (-1, 0, 0))
            3.141592653589793
    """
    v1_u = unit_vector(v1)
    v2_u = unit_vector(v2)
    return np.arccos(np.clip(np.dot(v1_u, v2_u), -1.0, 1.0))

# %%
os.mkdir('attention_movie')

# %%
# %%capture
colors = plt.cm.Reds(np.linspace(0.3, 1, 2001))


for t in np.arange(0, 4000, 10):
    fig, ax1 = plt.subplots()

    ax1.axis('square')
    ax1.axis('off')

    if t <= 2000:
        g = t
    elif t > 2000:
        g = 4000 - t

    a_readout = nengo.Alpha(0.02).filt(sim.data[a_probe])[t,:]
    b_readout = nengo.Alpha(0.02).filt(sim.data[b_probe])[t,:]
    wm_readout = nengo.Alpha(0.02).filt(sim.data[wm_probe])[t,:]

    origin = np.array([[0, 0, 0],[0, 0, 0]]) # origin point

    # Spiking (normalization)
    V_neural = a_readout
    #ax1.text(0, 1.4, 'Attentional gain', ha='center', size=20)

    ax1.quiver(*origin, V_neural[0], V_neural[1], scale=1, units='xy',
              color='black', width=0.03)

    circle = plt.Circle((0,0), radius=1, fill=False, alpha=0.3, zorder=1)
    ax1.add_patch(circle)

    # Spiking (normalization)
    V_neural = np.array([a_readout, wm_readout])
    angle = angle_between(V_neural[0,:], V_neural[1,:])
    norm = np.linalg.norm(V_neural[1])
    ax1.plot([np.cos(angle) * norm * V_neural[0,0], V_neural[1,0]], 
         [np.cos(angle) * norm * V_neural[0,1], V_neural[1,1]], 
         color='grey', alpha=1., ls='--', zorder=50-i)

    lim = 1.4
    ax1.set_xlim([-lim, lim])
    ax1.set_ylim([-lim, lim])

    V_neural = b_readout
    ax1.quiver(*origin, V_neural[0], V_neural[1], 
              color=colors[g], scale=1, units='xy', width=0.03)

    V_neural = wm_readout
    ax1.quiver(*origin, V_neural[0], V_neural[1], 
              color='black', scale=1, units='xy', width=0.03)

    line = [[(0, 0)]]
    # set up the proxy artist
    #lc = mcol.LineCollection(len(gain_list) * line, colors=colors, lw=10)
    # create the legend
    #leg = ax1.legend([lc], [r'$g_{s}$'], 
    #                 handler_map={type(lc): HandlerDashedLines()},
    #                 handlelength=4, handleheight=0.75, fontsize=24, loc=[0.15, -0.15])

    fig.savefig(str(pathlib.Path().absolute())+'/attention_movie/{}'.format(t))

# %%
image_folder = 'attention_movie'
video_name = 'attention_movie.avi'

files = os.listdir(image_folder)
files = filter(lambda x:x.endswith(".png"), files)

images = [img for img in sorted(files, key=lambda x: int(os.path.splitext(x.split('.')[0])[0])) if img.endswith(".png")]
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

video = cv2.VideoWriter(video_name, 0, 20, (width,height))

for image in images:
    video.write(cv2.imread(os.path.join(image_folder, image)))

cv2.destroyAllWindows()
video.release()

# %% [markdown]
# ### Legendre Memory Network with Semantic Pointers

# %%
# Set parameters
D = 32
dim = 9


def stimulus_function(t):
    if t > 2.2 and t < 2.7:
        return 'A'
    elif t > 2.7 and t < 3.2:
        return 'B'
    elif t > 3.2 and t < 3.7:
        return 'C'
    elif t > 3.7 and t < 4.2:
        return 'D'
    elif t > 4.2 and t < 4.7:
        return 'E'
    elif t > 4.7 and t < 5.2:
        return 'F'
    elif t > 5.2 and t < 5.7:
        return 'G'
    else:
        return 0

# %%
vocab = spa.Vocabulary(D)
letters = string.ascii_uppercase
letters = letters[0:7]
vocab.populate(";".join(letters))

# %%
# %%capture

LMU_timing().run(dimensions=dim,
                 D=D,
                 full_output=True,
                 gain_i=1.,
                 effective_theta=2.,
                 vocab=vocab,
                 task_type = 'retrospective',
                 stimulus_function=stimulus_function,
                 data_dir='lmu_spa',
                 trial_duration=6.)

# %%
retrospective_data = pytry.read('lmu_spa')

# %%
retrospective_dt = pd.DataFrame(retrospective_data)

# %%
def readout_window(state, D, readout_time, dim, sp):
    rw = nengolib.networks.RollingWindow(n_neurons=100,
                                             theta = 1,
                                             dimensions=dim,
                                             process=None,
                                             legendre=True,
                                             realizer=nengolib.signal.realizers.Identity())
    basis = rw.basis()
    
    Dhistory = []
    for d in range(0, D):
        Dhistory.append(basis * nengo.Alpha(0.05).filt(state)[readout_time, d, :])
    
    sp_coeff = []
    for d in range(0, dim):
        sp_coeff.append(spa.similarity(nengo.Alpha(0.05).filt(state)[readout_time, :, d], 
                                   sp,
                                   normalize=False)[0])
    
    history = np.sum(basis * np.asarray(sp_coeff), axis=1)[::-1]
    
    return history, Dhistory

# %%
# 
retro_state_input = []
retro_state = []

retro_state_input.append(retrospective_dt['state'].values[0])
retro_state.append(retrospective_dt['x'].values[0])

# %%
sp_list = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
temporal_window = []
history_matrix = []
for sp in sp_list:
    temp, hm = readout_window(np.moveaxis(retro_state[0], 1, 0), D, 2999, dim, vocab[sp].v)
    temporal_window.append(temp)
    history_matrix.append(hm)
    
hm = np.sum(np.asarray(history_matrix[0]), axis=2)

# %%
fig = plt.figure(constrained_layout=False, figsize=(16, 20))
gs = fig.add_gridspec(9, 4, wspace=0, hspace=0.5)

t = 3000
colors = plt.cm.GnBu(np.linspace(0.2, 1, num=dim))

ax1 = fig.add_subplot(gs[0:2,:])
ax2 = fig.add_subplot(gs[2:4,:])
ax3 = fig.add_subplot(gs[5:7,1:3])
ax4 = fig.add_subplot(gs[7:9,1:3])
#ax5 = fig.add_subplot(gs[9:11,1:3], sharey=ax4)

trange = np.arange(0, 4., 0.001)
ax1.plot(trange, 
         nengo.Alpha(0.01).filt(spa.similarity(retro_state_input[0], vocab)),
         lw=3)
ax1.axvline(x = int(t/1000), linestyle='--', c='black', alpha=0.5)

ax2.axvline(x = int(t/1000), linestyle='--', c='black', alpha = 0.5)
for i in [0, 1, 6]:
    for j in range(dim):
        ax2.plot(trange, 
                 nengo.Alpha(0.05).filt(np.moveaxis(retro_state[0], 1, 0))[:, i, j],
                 alpha=0.3, color=colors[j])
        
        ax2.scatter(int(t/1000), 
                    nengo.Alpha(0.05).filt(np.moveaxis(retro_state[0], 1, 0))[t, i, j], 120, edgecolors='black', zorder=20,
                    color=colors[j])
    
#for i in range(0, dim):
    #ax3.plot(np.linspace(1, 3, num=1000), B[::-1, i], lw=2,
    #         color=colors[i], label='{}'.format(i))
    #ax4.plot(np.linspace(1, 3, num=1000), sim.data[p_x][t,i] * B[::-1,i], lw=2,
    #         color=colors[i])

colors = plt.cm.GnBu(np.linspace(0.1, 1., num=D))
trange = np.linspace(1, 3, 1000)

for i in range(D):
    ax3.plot(trange, hm.T[:,i], color=colors[i], alpha=0.3)    

for i in range(len(sp_list)):
    ax4.plot(trange, temporal_window[i],
             lw=2.5, label=sp_list[i])

#line = [[(0, 0)]]
# set up the proxy artist
#lc = mcol.LineCollection(q * line, colors=colors)
# create the legend
#leg = ax3.legend([lc], ['dim'], handler_map={type(lc): HandlerDashedLines()},
#           handlelength=10, handleheight=0.75, fontsize=18, loc='lower left')

ax1.tick_params(axis='both', which='major', labelsize=16)
ax2.tick_params(axis='both', which='major', labelsize=16)
ax3.tick_params(axis='both', which='major', labelsize=16)
ax4.tick_params(axis='both', which='major', labelsize=16)
#ax5.tick_params(axis='both', which='major', labelsize=16)

ax1.set_xticks([])
ax2.set_xlabel('real time (s)', size=20)
ax3.set_xticks(np.linspace(1, 3, num=10))
ax3.set_xticklabels([])
ax3.set_ylim([-0.5, 0.5])
ax4.set_xticks(np.linspace(1, 3, num=10))
ax4.set_xticklabels([r'$-\theta$', '', '', '', '', '', '', '', '', 0], 
                    size=24)
ax4.set_xlabel('internal time', size=20)

ax3.set_facecolor('whitesmoke')
ax4.set_facecolor('whitesmoke')
#ax5.set_facecolor('whitesmoke')

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)
#ax3.spines['right'].set_visible(False)
#ax4.spines['top'].set_visible(False)
#ax4.spines['right'].set_visible(False)
#ax5.spines['top'].set_visible(False)
#ax5.spines['right'].set_visible(False)

#fig.savefig('legendre_memory_sp_demo.svg')
